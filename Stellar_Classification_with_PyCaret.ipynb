# %% [markdown]
# # Stellar Classification using PyCaret
# ## Classification of stars based on their spectral characteristics.
# This version was made after the Kaggle Version without using PyCaret and was made in colab.

# %%
#pip install pycaret

# %%
# import libraries
import pandas as pd
import numpy as np
from pycaret.classification import *

# %%
# load data
df=pd.read_csv("/content/star_classification.csv")
df.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# ...

# %%
setup(df, target="class")
# Out:
#                                Description                       Value
# 0                               session_id                        7655
# 1                                   Target                       class
# 2                              Target Type                  Multiclass
# 3                            Label Encoded  GALAXY: 0, QSO: 1, STAR: 2
# 4                            Original Data                (100000, 18)
# 5                           Missing Values                       False
# 6                         Numeric Features                          15
# 7                     Categorical Features                           2
# 8                         Ordinal Features                       False
# 9                High Cardinality Features                       False
# 10                 High Cardinality Method                        None
# 11                   Transformed Train Set                 (69999, 18)
# ...

# %%
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9751  0.9936  0.9665  0.9750
# rf               Random Forest Classifier    0.9738  0.9926  0.9649  0.9737
# gbc          Gradient Boosting Classifier    0.9718  0.9925  0.9584  0.9718
# et                 Extra Trees Classifier    0.9644  0.9889  0.9529  0.9644
# dt               Decision Tree Classifier    0.9594  0.9626  0.9531  0.9595
# lda          Linear Discriminant Analysis    0.8221  0.9190  0.7326  0.8422
# knn                K Neighbors Classifier    0.7048  0.7760  0.5841  0.6967
# ada                  Ada Boost Classifier    0.6133  0.7146  0.5468  0.6540
# lr                    Logistic Regression    0.6026  0.5799  0.3647  0.4557
# nb                            Naive Bayes    0.5944  0.0000  0.3333  0.3533
# qda       Quadratic Discriminant Analysis    0.5944  0.0000  0.3333  0.3533
# ...

# %% [markdown]
# In this model using PyCaret, the best result shows Light Grading Boosting Machine with an accuracy of 97,51%, which is slightly less than the model we build on kaggle with an acc of 98% with the GradientBoosting Classifier. In this case the GBC scored an acc of 97,2%.

# %%
dt=create_model('dt',fold=10) # runs the data 10 times and shows best results (K-Folds Cross-Validation)
# divides the data part by part while training
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9624  0.9651  0.9562  0.9624  0.9624  0.9334  0.9334
# 1       0.9589  0.9614  0.9510  0.9588  0.9588  0.9269  0.9270
# 2       0.9617  0.9648  0.9556  0.9617  0.9617  0.9321  0.9321
# 3       0.9621  0.9651  0.9562  0.9622  0.9622  0.9329  0.9329
# 4       0.9593  0.9635  0.9550  0.9595  0.9594  0.9280  0.9280
# 5       0.9566  0.9599  0.9495  0.9565  0.9565  0.9230  0.9230
# 6       0.9596  0.9621  0.9522  0.9595  0.9596  0.9282  0.9282
# 7       0.9619  0.9649  0.9561  0.9620  0.9619  0.9324  0.9324
# 8       0.9561  0.9604  0.9508  0.9564  0.9562  0.9224  0.9224
# 9       0.9559  0.9588  0.9479  0.9558  0.9558  0.9217  0.9217
# Mean    0.9594  0.9626  0.9531  0.9595  0.9595  0.9281  0.9281
# Std     0.0024  0.0023  0.0030  0.0024  0.0024  0.0043  0.0043
# INFO:logs:create_model_container: 16
# INFO:logs:master_model_container: 16
# INFO:logs:display_container: 3
# ...

# %%
dt=create_model('dt')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9624  0.9651  0.9562  0.9624  0.9624  0.9334  0.9334
# 1       0.9589  0.9614  0.9510  0.9588  0.9588  0.9269  0.9270
# 2       0.9617  0.9648  0.9556  0.9617  0.9617  0.9321  0.9321
# 3       0.9621  0.9651  0.9562  0.9622  0.9622  0.9329  0.9329
# 4       0.9593  0.9635  0.9550  0.9595  0.9594  0.9280  0.9280
# 5       0.9566  0.9599  0.9495  0.9565  0.9565  0.9230  0.9230
# 6       0.9596  0.9621  0.9522  0.9595  0.9596  0.9282  0.9282
# 7       0.9619  0.9649  0.9561  0.9620  0.9619  0.9324  0.9324
# 8       0.9561  0.9604  0.9508  0.9564  0.9562  0.9224  0.9224
# 9       0.9559  0.9588  0.9479  0.9558  0.9558  0.9217  0.9217
# Mean    0.9594  0.9626  0.9531  0.9595  0.9595  0.9281  0.9281
# Std     0.0024  0.0023  0.0030  0.0024  0.0024  0.0043  0.0043
# INFO:logs:create_model_container: 17
# INFO:logs:master_model_container: 17
# INFO:logs:display_container: 4
# ...

# %% [markdown]
# Mean Accuracy is at 96%
